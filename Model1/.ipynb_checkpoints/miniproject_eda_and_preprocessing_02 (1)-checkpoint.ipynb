# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
# %matplotlib inline

# %% [markdown]
# ### Loading CSV File in Pandas DataFrame
# ### Dataset ref: https://www.eia.gov/coal/data.php

# %%
df = pd.read_csv(r'coalUS.csv',encoding = "ISO-8859-1")
df.head()
# Out:
#    Year  MSHAID                        MineName    STATE MineCounty  \
# 0  2013  103381            Tacoa Highwall Miner  Alabama       Bibb
# 1  2013  103404                Reid School Mine  Alabama     Blount
# 2  2013  100759  North River #1 Underground Min  Alabama    Fayette
# 3  2013  103246                      Bear Creek  Alabama   Franklin
# 4  2013  103451                     Knight Mine  Alabama   Franklin
#
#                            MineStatus     MineType  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                     CompanyType               OperationType  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# 2  Indepedent Producer Operator  Mine and Preparation Plant
# 3  Indepedent Producer Operator                   Mine only
# 4  Indepedent Producer Operator                   Mine only
#
#                  OperatingCompany  \
# 0         Jesse Creek Mining, Llc
# 1   Taft Coal Sales & Associates,
# 2        Jim Walter Resources Inc
# 3  Birmingham Coal & Coke Co., In
# 4  Birmingham Coal & Coke Co., In
#
#                              OperatingCompanyAddress UnionCode  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...      UNIT
# 2               3114 County Rd 63 S, Berry, AL 35546      UNIT
# 3           912 Edenton Street, Birmingham, AL 35242
# 4                       P.O. Box 354, Lynn, AL 35242
#
#       CoalSupplyRegion  Production  AverageEmployee  LabourHours  latitute  \
# 0  Appalachia Southern       56004               10        22392   32.3182
# 1  Appalachia Southern       28807               18        28447   32.3182
# 2  Appalachia Southern     1440115              183       474784   32.3182
# 3  Appalachia Southern       87587               13        29193   32.3182
# 4  Appalachia Southern      147499               27        46393   32.3182
#
#    longitude
# 0    86.9023
# 1    86.9023
# 2    86.9023
# 3    86.9023
# 4    86.9023

# %% [markdown]
# ### Our Dataset Contains
# #### 7656 Rows
# #### 18 Columns

# %%
df.shape
# Out:
# (7656, 18)

# %% [markdown]
# ### Here we can see that we have two columns UnionCode & CoalSupplyRegion which have null values.

# %%
df.isnull().sum()
# Out:
# Year                          0
# MSHAID                        0
# MineName                      0
# STATE                         0
# MineCounty                    0
# MineStatus                    0
# MineType                      0
# CompanyType                   0
# OperationType                 0
# OperatingCompany              0
# OperatingCompanyAddress       0
# UnionCode                  5766
# CoalSupplyRegion              1
# Production                    0
# AverageEmployee               0
# LabourHours                   0
# latitute                      0
# longitude                     0
# dtype: int64

# %% [markdown]
# ### The describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame. Here, we can see mean & Standard Deviation does not Deviate largly. Quartile Range 25% to 75% also doesn't Deviate.

# %%
df.describe()
# Out:
#               Year        MSHAID    Production  AverageEmployee   LabourHours  \
# count  7656.000000  7.656000e+03  7.656000e+03      7656.000000  7.656000e+03
# mean   2015.667320  3.058066e+06  7.655730e+05        57.051855  1.261416e+05
# std       2.023044  1.436422e+06  4.507137e+06       119.671463  2.692428e+05
# min    2013.000000  1.003290e+05  0.000000e+00         0.000000  8.000000e+00
# 25%    2014.000000  1.519164e+06  0.000000e+00         6.000000  9.298500e+03
# 50%    2015.000000  3.608248e+06  3.251750e+04        16.000000  3.270950e+04
# 75%    2017.000000  4.407313e+06  2.459240e+05        47.000000  1.065570e+05
# max    2019.000000  5.000030e+06  1.179655e+08      1628.000000  3.349283e+06
#
#           latitute    longitude
# count  7656.000000  7656.000000
# mean     38.837245    61.768806
# std       2.516903    56.306354
# min      30.984300   -77.194527
# 25%      37.735300    78.656900
# 50%      38.368600    81.699900
# 75%      41.203323    84.298700
# max      64.200800   149.493700

# %% [markdown]
# ### Here is the summary of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7656 entries, 0 to 7655
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     7656 non-null   int64
#  1   MSHAID                   7656 non-null   int64
#  2   MineName                 7656 non-null   object
#  3   STATE                    7656 non-null   object
#  4   MineCounty               7656 non-null   object
#  5   MineStatus               7656 non-null   object
#  6   MineType                 7656 non-null   object
#  7   CompanyType              7656 non-null   object
#  8   OperationType            7656 non-null   object
#  9   OperatingCompany         7656 non-null   object
#  10  OperatingCompanyAddress  7656 non-null   object
#  11  UnionCode                1890 non-null   object
#  12  CoalSupplyRegion         7655 non-null   object
#  13  Production               7656 non-null   int64
#  14  AverageEmployee          7656 non-null   int64
#  15  LabourHours              7656 non-null   int64
#  16  latitute                 7656 non-null   float64
#  17  longitude                7656 non-null   float64
# dtypes: float64(2), int64(5), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Here, We did Correlation to understand the relationships between independant & Dependant variables. The statistical relationship between two variables is referred to as their correlation. So here, Since our target variable/Dependant Variable is "Production", we are doing correlation to understand the relationship between other independant features in the dataset.
# #### Here you can see that AverageEmployee & LabourHour are more correlated to our target variable & the other attributes are less correlated.

# %%
corr=df.corr()['Production']
corr.abs().sort_values(ascending=False)[1:]
# Out:
# AverageEmployee    0.705613
# LabourHours        0.670527
# latitute           0.142736
# longitude          0.079709
# MSHAID             0.065876
# Year               0.006391
# Name: Production, dtype: float64

# %% [markdown]
# ### Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. So here, in production cell, AverageEmployee & Labour Hours are brighter in color hence more correlated.

# %%
fig, ax = plt.subplots(figsize=(30,20))
sns.heatmap(df.corr(), annot=True, ax=ax);

# %% [markdown]
# ### A barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean. It can also be understood as a visualization of the group by action. In this plot we chose a categorical column for the x-axis(State) and a numerical column for the y-axis(Production), and we see that it creates a plot taking a mean per categorical column.
# ### So Here we can see that average production of coal from 2013-2019 is distributed state wise. Here, we can see that the Wyoming State has the Mean Highest Coal Production and Pennsylvania has the Mean Lowest Coal Production.

# %%
from sklearn.cluster import KMeans
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES')
sns.barplot(x=df['STATE'], y=df['Production'])
#plt.legend(loc='upper left')
plt.show()

# %%
#le = LabelEncoder()
#df['STATE']= le.fit_transform(df['STATE'])

# %%
df.head()
# Out:
#    Year  MSHAID                        MineName    STATE MineCounty  \
# 0  2013  103381            Tacoa Highwall Miner  Alabama       Bibb
# 1  2013  103404                Reid School Mine  Alabama     Blount
# 2  2013  100759  North River #1 Underground Min  Alabama    Fayette
# 3  2013  103246                      Bear Creek  Alabama   Franklin
# 4  2013  103451                     Knight Mine  Alabama   Franklin
#
#                            MineStatus     MineType  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                     CompanyType               OperationType  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# 2  Indepedent Producer Operator  Mine and Preparation Plant
# 3  Indepedent Producer Operator                   Mine only
# 4  Indepedent Producer Operator                   Mine only
#
#                  OperatingCompany  \
# 0         Jesse Creek Mining, Llc
# 1   Taft Coal Sales & Associates,
# 2        Jim Walter Resources Inc
# 3  Birmingham Coal & Coke Co., In
# 4  Birmingham Coal & Coke Co., In
#
#                              OperatingCompanyAddress UnionCode  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...      UNIT
# 2               3114 County Rd 63 S, Berry, AL 35546      UNIT
# 3           912 Edenton Street, Birmingham, AL 35242
# 4                       P.O. Box 354, Lynn, AL 35242
#
#       CoalSupplyRegion  Production  AverageEmployee  LabourHours  latitute  \
# 0  Appalachia Southern       56004               10        22392   32.3182
# 1  Appalachia Southern       28807               18        28447   32.3182
# 2  Appalachia Southern     1440115              183       474784   32.3182
# 3  Appalachia Southern       87587               13        29193   32.3182
# 4  Appalachia Southern      147499               27        46393   32.3182
#
#    longitude
# 0    86.9023
# 1    86.9023
# 2    86.9023
# 3    86.9023
# 4    86.9023

# %%
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES FOR 2013')
sns.barplot(df['STATE'] [df['Year'] == 2013], y=df['Production'] [df['Year'] == 2013],label='Year 2013')
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\SHREE\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES FOR 2014')
sns.barplot(df['STATE'] [df['Year'] == 2014], y=df['Production'] [df['Year'] == 2014],label='Year 2014')
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\SHREE\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES FOR 2015')
sns.barplot(df['STATE'] [df['Year'] == 2015], y=df['Production'] [df['Year'] == 2015],label='Year 2015')
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\SHREE\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES FOR 2016')
sns.barplot(df['STATE'] [df['Year'] == 2016], y=df['Production'] [df['Year'] == 2016],label='Year 2016')
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\SHREE\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES FOR 2017')
sns.barplot(df['STATE'] [df['Year'] == 2017], y=df['Production'] [df['Year'] == 2017],label='Year 2017')
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\SHREE\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES FOR 2018')
sns.barplot(df['STATE'] [df['Year'] == 2018], y=df['Production'] [df['Year'] == 2018],label='Year 2018')
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\SHREE\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,25))
plt.title('PRODUCTION OF COAL MINES DISTRIBUTED ACCOURDING TO THE STATES FOR 2019')
sns.barplot(df['STATE'] [df['Year'] == 2019], y=df['Production'] [df['Year'] == 2019],label='Year 2019')
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\SHREE\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#df.rename(columns = {'Average Employees': 'Average_Employees'}, inplace = True)

# %%
#df.rename(columns = {'Mine State': 'Mine_State'}, inplace = True)

# %%
df1 = df.copy(deep=True)
df2 = df1.copy(deep=True)
df3 = df2.copy(deep=True)
df4 = df3.copy(deep=True)
df5 = df4.copy(deep=True)
df6 = df5.copy(deep=True)
df7 = df5.copy(deep=True)

# %%
km = KMeans(n_clusters = 3)
km
# Out:
# KMeans(n_clusters=3)

# %%
le = LabelEncoder()
df1['STATE']= le.fit_transform(df1['STATE'])

# %%
y_predicted = km.fit_predict(df1[['STATE','Production']])
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df1['cluster'] = y_predicted
df1.head()
# Out:
#    Year  MSHAID                        MineName  STATE MineCounty  \
# 0  2013  103381            Tacoa Highwall Miner      0       Bibb
# 1  2013  103404                Reid School Mine      0     Blount
# 2  2013  100759  North River #1 Underground Min      0    Fayette
# 3  2013  103246                      Bear Creek      0   Franklin
# 4  2013  103451                     Knight Mine      0   Franklin
#
#                            MineStatus     MineType  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                     CompanyType               OperationType  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# 2  Indepedent Producer Operator  Mine and Preparation Plant
# 3  Indepedent Producer Operator                   Mine only
# 4  Indepedent Producer Operator                   Mine only
#
#                  OperatingCompany  \
# 0         Jesse Creek Mining, Llc
# 1   Taft Coal Sales & Associates,
# 2        Jim Walter Resources Inc
# 3  Birmingham Coal & Coke Co., In
# 4  Birmingham Coal & Coke Co., In
#
#                              OperatingCompanyAddress UnionCode  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...      UNIT
# 2               3114 County Rd 63 S, Berry, AL 35546      UNIT
# 3           912 Edenton Street, Birmingham, AL 35242
# 4                       P.O. Box 354, Lynn, AL 35242
#
#       CoalSupplyRegion  Production  AverageEmployee  LabourHours  latitute  \
# 0  Appalachia Southern       56004               10        22392   32.3182
# 1  Appalachia Southern       28807               18        28447   32.3182
# 2  Appalachia Southern     1440115              183       474784   32.3182
# 3  Appalachia Southern       87587               13        29193   32.3182
# 4  Appalachia Southern      147499               27        46393   32.3182
#
#    longitude  cluster
# 0    86.9023        0
# 1    86.9023        0
# 2    86.9023        0
# 3    86.9023        0
# 4    86.9023        0

# %%
km.cluster_centers_
# Out:
# array([[1.66595428e+01, 2.86651846e+05],
#        [2.70000000e+01, 9.27928881e+07],
#        [1.78674699e+01, 9.81088144e+06]])

# %%
dfx = df1[df1.cluster==0]
dfy = df1[df1.cluster==1]



plt.scatter(dfx['STATE'],dfx['Production'],color='green')
plt.scatter(dfy['STATE'],dfy['Production'],color='red')


plt.xlabel('LabourHours')
plt.ylabel('Production')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='+',label = 'centroids')
plt.legend()

# %%
k_rng = range(1,10)
sse = []
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df1[['LabourHours','Production']])
    sse.append(km.inertia_)

# %%
plt.xlabel('k')
plt.ylabel('sum of squared error')
plt.plot(k_rng,sse)

# %%
#scaler = StandardScaler()
#df2.iloc[:,[0]]=scaler.fit_transform(df2.iloc[:,[0]])
#print(df2.iloc[:,[0]])

# %%
#df2.head()

# %%
kme = KMeans(n_clusters = 3)
kme
# Out:
# KMeans(n_clusters=3)

# %%
y_pred = kme.fit_predict(df2[['Year','Production']])
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df2['cluster'] = y_pred
df2.head()
# Out:
#    Year  MSHAID                        MineName    STATE MineCounty  \
# 0  2013  103381            Tacoa Highwall Miner  Alabama       Bibb
# 1  2013  103404                Reid School Mine  Alabama     Blount
# 2  2013  100759  North River #1 Underground Min  Alabama    Fayette
# 3  2013  103246                      Bear Creek  Alabama   Franklin
# 4  2013  103451                     Knight Mine  Alabama   Franklin
#
#                            MineStatus     MineType  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                     CompanyType               OperationType  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# 2  Indepedent Producer Operator  Mine and Preparation Plant
# 3  Indepedent Producer Operator                   Mine only
# 4  Indepedent Producer Operator                   Mine only
#
#                  OperatingCompany  \
# 0         Jesse Creek Mining, Llc
# 1   Taft Coal Sales & Associates,
# 2        Jim Walter Resources Inc
# 3  Birmingham Coal & Coke Co., In
# 4  Birmingham Coal & Coke Co., In
#
#                              OperatingCompanyAddress UnionCode  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...      UNIT
# 2               3114 County Rd 63 S, Berry, AL 35546      UNIT
# 3           912 Edenton Street, Birmingham, AL 35242
# 4                       P.O. Box 354, Lynn, AL 35242
#
#       CoalSupplyRegion  Production  AverageEmployee  LabourHours  latitute  \
# 0  Appalachia Southern       56004               10        22392   32.3182
# 1  Appalachia Southern       28807               18        28447   32.3182
# 2  Appalachia Southern     1440115              183       474784   32.3182
# 3  Appalachia Southern       87587               13        29193   32.3182
# 4  Appalachia Southern      147499               27        46393   32.3182
#
#    longitude  cluster
# 0    86.9023        0
# 1    86.9023        0
# 2    86.9023        0
# 3    86.9023        0
# 4    86.9023        0

# %%
kme.cluster_centers_
# Out:
# array([[2.01565972e+03, 2.87299421e+05],
#        [2.01600000e+03, 9.27928881e+07],
#        [2.01587500e+03, 9.82997846e+06]])

# %%
dfa = df2[df2.cluster==0]
dfb = df2[df2.cluster==1]



plt.scatter(dfa['Year'],dfa['Production'],color='green')
plt.scatter(dfb['Year'],dfb['Production'],color='red')


plt.xlabel('Year')
plt.ylabel('Production')
plt.scatter(kme.cluster_centers_[:,0],kme.cluster_centers_[:,1],color='purple',marker='+',label = 'centroids')
plt.legend()

# %%
k_rng = range(1,10)
sse = []
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df2[['Year','Production']])
    sse.append(km.inertia_)

# %%
plt.xlabel('k')
plt.ylabel('sum of squared error')
plt.plot(k_rng,sse)

# %%
kms = KMeans(n_clusters = 4)
kms
# Out:
# KMeans(n_clusters=4)

# %%
#scaler = StandardScaler()
#df3.iloc[:,[0]]=scaler.fit_transform(df3.iloc[:,[0]])
#print(df3.iloc[:,[0]])

# %%
#scaler = StandardScaler()
#df3.iloc[:,[3]]=scaler.fit_transform(df3.iloc[:,[3]])
#print(df3.iloc[:,[3]])

# %%
#df3.head()

# %%
le = LabelEncoder()
df3['STATE']= le.fit_transform(df3['STATE'])

# %%
y_predict = kms.fit_predict(df3[['STATE','Year','Production']])
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
kms.cluster_centers_
# Out:
# array([[1.66635372e+01, 2.01565760e+03, 2.10922590e+05],
#        [2.70000000e+01, 2.01600000e+03, 9.27928881e+07],
#        [2.25087719e+01, 2.01601754e+03, 1.77497654e+07],
#        [1.64795322e+01, 2.01580117e+03, 5.91426206e+06]])

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(kms.cluster_centers_[:, 0],
            kms.cluster_centers_[:, 1],
            kms.cluster_centers_[:, 2],
            s = 400,
            marker='*',
            c='red',
            label='centroids')
scatter = ax.scatter(df3['STATE'],df3['Year'], df3['Production'],
                     c=y_predict,s=20, cmap='winter')


ax.set_title('CLUSTERING OF PRODUCTION OF COAL ON STATE AND YEAR',fontsize = 15)
ax.set_xlabel('STATE',fontsize = 15)
ax.set_ylabel('Year',fontsize = 15)
ax.set_zlabel('Production',fontsize = 15)
ax.legend()
plt.show()

# %%
k_rng = range(1,10)
sse = []
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df3[['STATE','Year','Production']])
    sse.append(km.inertia_)

# %%
plt.xlabel('k')
plt.ylabel('sum of squared error')
plt.plot(k_rng,sse)

# %%
kmx = KMeans(n_clusters = 3)
kmx
# Out:
# KMeans(n_clusters=3)

# %%
y_pr = kmx.fit_predict(df4[['latitute','longitude','Production']])
y_pr
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
kmx.cluster_centers_
# Out:
# array([[3.87586514e+01, 6.09526479e+01, 2.86651846e+05],
#        [4.30760000e+01, 1.07290300e+02, 9.27928881e+07],
#        [4.09324172e+01, 8.34417110e+01, 9.81088144e+06]])

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(kmx.cluster_centers_[:, 0],
            kmx.cluster_centers_[:, 1],
            kmx.cluster_centers_[:, 2],
            
            s = 400,
            marker='*',
            c='red',
            label='centroids')
scatter = ax.scatter(df4['latitute'],df4['longitude'], df4['Production'],
                     c=y_pr,s=20, cmap='winter')


ax.set_title('CLUSTERING OF PRODUCTION OF COAL LATITUDE AND LONGITUDE WISE',fontsize = 15)
ax.set_xlabel('latitute',fontsize = 15)
ax.set_ylabel('longitude',fontsize = 15)
ax.set_zlabel('Production',fontsize = 15)
ax.legend()
plt.show()

# %%
k_rng = range(1,10)
sse = []
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df4[['latitute','longitude','Production']])
    sse.append(km.inertia_)

# %%
plt.xlabel('k')
plt.ylabel('sum of squared error')
plt.plot(k_rng,sse)

# %%
kmc = KMeans(n_clusters = 4)
kmc
# Out:
# KMeans(n_clusters=4)

# %%
df5.head()
# Out:
#    Year  MSHAID                        MineName    STATE MineCounty  \
# 0  2013  103381            Tacoa Highwall Miner  Alabama       Bibb
# 1  2013  103404                Reid School Mine  Alabama     Blount
# 2  2013  100759  North River #1 Underground Min  Alabama    Fayette
# 3  2013  103246                      Bear Creek  Alabama   Franklin
# 4  2013  103451                     Knight Mine  Alabama   Franklin
#
#                            MineStatus     MineType  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                     CompanyType               OperationType  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# 2  Indepedent Producer Operator  Mine and Preparation Plant
# 3  Indepedent Producer Operator                   Mine only
# 4  Indepedent Producer Operator                   Mine only
#
#                  OperatingCompany  \
# 0         Jesse Creek Mining, Llc
# 1   Taft Coal Sales & Associates,
# 2        Jim Walter Resources Inc
# 3  Birmingham Coal & Coke Co., In
# 4  Birmingham Coal & Coke Co., In
#
#                              OperatingCompanyAddress UnionCode  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...      UNIT
# 2               3114 County Rd 63 S, Berry, AL 35546      UNIT
# 3           912 Edenton Street, Birmingham, AL 35242
# 4                       P.O. Box 354, Lynn, AL 35242
#
#       CoalSupplyRegion  Production  AverageEmployee  LabourHours  latitute  \
# 0  Appalachia Southern       56004               10        22392   32.3182
# 1  Appalachia Southern       28807               18        28447   32.3182
# 2  Appalachia Southern     1440115              183       474784   32.3182
# 3  Appalachia Southern       87587               13        29193   32.3182
# 4  Appalachia Southern      147499               27        46393   32.3182
#
#    longitude
# 0    86.9023
# 1    86.9023
# 2    86.9023
# 3    86.9023
# 4    86.9023

# %%
le = LabelEncoder()
df5['STATE']= le.fit_transform(df5['STATE'])

# %%
y_p = kmc.fit_predict(df5[['STATE','AverageEmployee','LabourHours']])
y_p
# Out:
# array([2, 2, 0, ..., 0, 0, 0])

# %%
kmc.cluster_centers_
# Out:
# array([[1.74382716e+01, 1.73904938e+02, 3.90271040e+05],
#        [1.55101351e+01, 4.44047297e+02, 1.01305154e+06],
#        [1.66684049e+01, 2.01174847e+01, 4.22663399e+04],
#        [1.99000000e+01, 1.11073333e+03, 2.47269293e+06]])

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(kmc.cluster_centers_[:, 0],
            kmc.cluster_centers_[:, 1],
            kmc.cluster_centers_[:, 2],
            s = 400,
            marker='*',
            c='red',
            label='centroids')
scatter = ax.scatter(df5['STATE'],df5['AverageEmployee'], df5['LabourHours'],
                     c=y_p,s=20, cmap='winter')


ax.set_title('CLUSTERING OF AVERAGE EMPLOYEES AND THEIR LABOUR HOURS ON STATE MINES',fontsize = 15)
ax.set_xlabel('STATE',fontsize = 15)
ax.set_ylabel('AverageEmployee',fontsize = 15)
ax.set_zlabel('LabourHours',fontsize = 15)
ax.legend()
plt.show()

# %%
k_rng = range(1,10)
sse = []
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df5[['STATE','AverageEmployee','LabourHours']])
    sse.append(km.inertia_)

# %%
plt.xlabel('k')
plt.ylabel('sum of squared error')
plt.plot(k_rng,sse)

# %%
kmn = KMeans(n_clusters = 3)
kmn
# Out:
# KMeans(n_clusters=3)

# %%
y_pi = kmn.fit_predict(df6[['Production','AverageEmployee','LabourHours']])
y_pi
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
kmn.cluster_centers_
# Out:
# array([[2.87299421e+05, 4.23117392e+01, 9.35688308e+04],
#        [9.27928881e+07, 1.35700000e+03, 2.81783050e+06],
#        [9.82997846e+06, 4.23137097e+02, 9.45332899e+05]])

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(kmn.cluster_centers_[:, 0],
            kmn.cluster_centers_[:, 1],
            kmn.cluster_centers_[:, 2],
            s = 400,
            marker='*',
            c='red',
            label='centroids')
scatter = ax.scatter(df6['Production'],df6['AverageEmployee'], df6['LabourHours'],
                     c=y_p,s=20, cmap='winter')


ax.set_title('CLUSTERING OF AVERAGE EMPLOYEES AND THEIR LABOUR HOURS ON COAL PRODUCTION',fontsize = 15)
ax.set_xlabel('Production',fontsize = 15)
ax.set_ylabel('AverageEmployee',fontsize = 15)
ax.set_zlabel('LabourHours',fontsize = 15)
ax.legend()
plt.show()

# %%
kmz = KMeans(n_clusters = 3)
kmz
# Out:
# KMeans(n_clusters=3)

# %%
le = LabelEncoder()
df7['STATE']= le.fit_transform(df7['STATE'])

# %%
y_pz = kmz.fit_predict(df7[['Production','STATE','LabourHours']])
y_pz
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
kmz.cluster_centers_
# Out:
# array([[2.86651846e+05, 1.66595428e+01, 9.34758135e+04],
#        [9.27928881e+07, 2.70000000e+01, 2.81783050e+06],
#        [9.81088144e+06, 1.78674699e+01, 9.44673916e+05]])

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(kmz.cluster_centers_[:, 0],
            kmz.cluster_centers_[:, 1],
            kmz.cluster_centers_[:, 2],
            s = 400,
            marker='*',
            c='red',
            label='centroids')
scatter = ax.scatter(df7['Production'],df7['STATE'], df7['LabourHours'],
                     c=y_pz,s=20, cmap='winter')


ax.set_title('CLUSTERING OF PRODUCTION OF STATES AND ITS LABOUR HOURS',fontsize = 15)
ax.set_xlabel('Production',fontsize = 15)
ax.set_ylabel('STATE',fontsize = 15)
ax.set_zlabel('LabourHours',fontsize = 15)
ax.legend()
plt.show()

# %%
df[['Production']].isna().sum()
# Out:
# Production    0
# dtype: int64

# %%
bins = [0,100,1000,100000,1000000,100000000]
group_names=["zerotohun","huntothou","thoutolk","lktocr","crtotencr"]
df['PRODUCTION']= pd.cut(df["Production"],bins,labels = group_names)
df
# Out:
#       Year   MSHAID                        MineName    STATE  MineCounty  \
# 0     2013   103381            Tacoa Highwall Miner  Alabama        Bibb
# 1     2013   103404                Reid School Mine  Alabama      Blount
# 2     2013   100759  North River #1 Underground Min  Alabama     Fayette
# 3     2013   103246                      Bear Creek  Alabama    Franklin
# 4     2013   103451                     Knight Mine  Alabama    Franklin
# ...    ...      ...                             ...      ...         ...
# 7651  2019  4801337              Antelope Coal Mine  Wyoming    Converse
# 7652  2019  4800086                   Kemmerer Mine  Wyoming     Lincoln
# 7653  2019  4800677                Jim Bridger Mine  Wyoming  Sweetwater
# 7654  2019  4801180   Black Butte And Leucite Hills  Wyoming  Sweetwater
# 7655  2019  4801646   Bridger Underground Coal Mine  Wyoming  Sweetwater
#
#                               MineStatus     MineType  \
# 0     Active, men working, not producing      Surface
# 1                  Permanently abandoned      Surface
# 2     Active, men working, not producing  Underground
# 3                                 Active      Surface
# 4                                 Active      Surface
# ...                                  ...          ...
# 7651                              Active      Surface
# 7652                              Active      Surface
# 7653                              Active      Surface
# 7654                              Active      Surface
# 7655                              Active  Underground
#
#                        CompanyType               OperationType  \
# 0     Indepedent Producer Operator                   Mine only
# 1     Indepedent Producer Operator                   Mine only
# 2     Indepedent Producer Operator  Mine and Preparation Plant
# 3     Indepedent Producer Operator                   Mine only
# 4     Indepedent Producer Operator                   Mine only
# ...                            ...                         ...
# 7651  Indepedent Producer Operator                   Mine only
# 7652          Operating Subsidiary  Mine and Preparation Plant
# 7653          Operating Subsidiary                   Mine only
# 7654          Operating Subsidiary                   Mine only
# 7655          Operating Subsidiary                   Mine only
#
#                     OperatingCompany  \
# 0            Jesse Creek Mining, Llc
# 1      Taft Coal Sales & Associates,
# 2           Jim Walter Resources Inc
# 3     Birmingham Coal & Coke Co., In
# 4     Birmingham Coal & Coke Co., In
# ...                              ...
# 7651  Navajo Transitional Energy Com
# 7652        Kemmerer Operations, Llc
# 7653            Bridger Coal Company
# 7654        Black Butte Coal Company
# 7655            Bridger Coal Company
#
#                                 OperatingCompanyAddress  \
# 0               1615 Kent Dairy Rd, Alabaster, AL 35007
# 1     3000 Riverchase Galleria Ste 1, Birmingham, AL...
# 2                  3114 County Rd 63 S, Berry, AL 35546
# 3              912 Edenton Street, Birmingham, AL 35242
# 4                          P.O. Box 354, Lynn, AL 35242
# ...                                                 ...
# 7651                  P.O. Box 3001, Gillette, WY 82717
# 7652                   P.O. Box 950, Kemmerer, WY 83101
# 7653               P.O. Box 68, Point Of Rock, WY 82942
# 7654               P.O. Box 98, Point Of Rock, WY 82942
# 7655       1088 Nine Mile Road, Point Of Rock, WY 82942
#
#                            UnionCode     CoalSupplyRegion  Production  \
# 0                                     Appalachia Southern       56004
# 1                               UNIT  Appalachia Southern       28807
# 2                               UNIT  Appalachia Southern     1440115
# 3                                     Appalachia Southern       87587
# 4                                     Appalachia Southern      147499
# ...                              ...                  ...         ...
# 7651                             NaN   Powder River Basin    23243371
# 7652  United Mine Workers Of America              Western     3067446
# 7653          Western Energy Workers              Western     2326392
# 7654                             NaN              Western     2307947
# 7655          Western Energy Workers              Western     2193565
#
#       AverageEmployee  LabourHours  latitute  longitude PRODUCTION
# 0                  10        22392   32.3182    86.9023   thoutolk
# 1                  18        28447   32.3182    86.9023   thoutolk
# 2                 183       474784   32.3182    86.9023  crtotencr
# 3                  13        29193   32.3182    86.9023   thoutolk
# 4                  27        46393   32.3182    86.9023     lktocr
# ...               ...          ...       ...        ...        ...
# 7651              591      1200850   43.0760   107.2903  crtotencr
# 7652              272       473600   43.0760   107.2903  crtotencr
# 7653              219       431217   43.0760   107.2903  crtotencr
# 7654              162       299134   43.0760   107.2903  crtotencr
# 7655              133       255308   43.0760   107.2903  crtotencr
#
# [7656 rows x 19 columns]

# %%
df['PRODUCTION'].dtype
# Out:
# CategoricalDtype(categories=['zerotohun', 'huntothou', 'thoutolk', 'lktocr', 'crtotencr'], ordered=True)

# %%
df.drop(['UnionCode'], axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# Year                          0
# MSHAID                        0
# MineName                      0
# STATE                         0
# MineCounty                    0
# MineStatus                    0
# MineType                      0
# CompanyType                   0
# OperationType                 0
# OperatingCompany              0
# OperatingCompanyAddress       0
# CoalSupplyRegion              1
# Production                    0
# AverageEmployee               0
# LabourHours                   0
# latitute                      0
# longitude                     0
# PRODUCTION                 2136
# dtype: int64

# %%
df.dropna(how = 'any',inplace = True)

# %%
df.shape
# Out:
# (5519, 18)

# %%
df.head()
# Out:
#    Year  MSHAID                        MineName    STATE MineCounty  \
# 0  2013  103381            Tacoa Highwall Miner  Alabama       Bibb
# 1  2013  103404                Reid School Mine  Alabama     Blount
# 2  2013  100759  North River #1 Underground Min  Alabama    Fayette
# 3  2013  103246                      Bear Creek  Alabama   Franklin
# 4  2013  103451                     Knight Mine  Alabama   Franklin
#
#                            MineStatus     MineType  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                     CompanyType               OperationType  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# 2  Indepedent Producer Operator  Mine and Preparation Plant
# 3  Indepedent Producer Operator                   Mine only
# 4  Indepedent Producer Operator                   Mine only
#
#                  OperatingCompany  \
# 0         Jesse Creek Mining, Llc
# 1   Taft Coal Sales & Associates,
# 2        Jim Walter Resources Inc
# 3  Birmingham Coal & Coke Co., In
# 4  Birmingham Coal & Coke Co., In
#
#                              OperatingCompanyAddress     CoalSupplyRegion  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007  Appalachia Southern
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...  Appalachia Southern
# 2               3114 County Rd 63 S, Berry, AL 35546  Appalachia Southern
# 3           912 Edenton Street, Birmingham, AL 35242  Appalachia Southern
# 4                       P.O. Box 354, Lynn, AL 35242  Appalachia Southern
#
#    Production  AverageEmployee  LabourHours  latitute  longitude PRODUCTION
# 0       56004               10        22392   32.3182    86.9023   thoutolk
# 1       28807               18        28447   32.3182    86.9023   thoutolk
# 2     1440115              183       474784   32.3182    86.9023  crtotencr
# 3       87587               13        29193   32.3182    86.9023   thoutolk
# 4      147499               27        46393   32.3182    86.9023     lktocr

# %%
df['PRODUCTION'].dtype
# Out:
# CategoricalDtype(categories=['zerotohun', 'huntothou', 'thoutolk', 'lktocr', 'crtotencr'], ordered=True)

# %%
#dummies = pd.get_dummies(df.STATE)
#dummies.head()

# %%
#df = pd.concat([df,dummies],axis='columns')
#df.head()

# %%
le = LabelEncoder()
df['PRODUCTION']= le.fit_transform(df['PRODUCTION'])

# %%
le = LabelEncoder()
df['STATE']= le.fit_transform(df['STATE'])

# %%
x = df.iloc[:,[0,3]]
y = df['PRODUCTION']

# %%
x
# Out:
#       Year  STATE
# 0     2013      0
# 1     2013      0
# 2     2013      0
# 3     2013      0
# 4     2013      0
# ...    ...    ...
# 7651  2019     27
# 7652  2019     27
# 7653  2019     27
# 7654  2019     27
# 7655  2019     27
#
# [5519 rows x 2 columns]

# %%
#from sklearn.preprocessing import StandardScaler
#x=StandardScaler().fit_transform(x)

# %%
y.head()
# Out:
# 0    3
# 1    3
# 2    0
# 3    3
# 4    2
# Name: PRODUCTION, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dst = DecisionTreeClassifier(max_depth = 10,random_state = 200,max_leaf_nodes = 13)
dst = dst.fit(x_train,y_train)

# %%
y_pre = dst.predict(x_test)
y_pre
# Out:
# array([3, 3, 0, ..., 0, 2, 0])

# %%
dst.score(x_test, y_test)
# Out:
# 0.5847826086956521

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pre))
print(classification_report(y_test, y_pre))
# Out:
# [[125   0  53  13   0]
#  [  0   0  10  28   0]
#  [ 50   0 272 201   0]
#  [ 23   0 191 410   0]
#  [  0   0   1   3   0]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.65      0.64       191
#            1       0.00      0.00      0.00        38
#            2       0.52      0.52      0.52       523
#            3       0.63      0.66      0.64       624
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.58      1380
#    macro avg       0.35      0.37      0.36      1380
# weighted avg       0.57      0.58      0.58      1380
# C:\Users\SHREE\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pickle
# Saving model to disk
pickle.dump(dst, open('model.pkl','wb'))

# %%
# Loading model to compare the results
modell = pickle.load(open('model.pkl','rb'))

# %%
print("Production of given year and state is",dst.predict([[2015,20]]),"Tons")
# Out:
# Production of given year and state is [3] Tons
